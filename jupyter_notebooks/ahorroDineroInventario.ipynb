# %%
import pandas as pd

# %%
FILE = 'stats_agrupacion_variabilidad_90_conf.xlsx'
df = pd.read_excel(FILE).drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#        ID_SKU_VENTA DESCR_CENDIST  STOCK_PRE  STOCK_POST  STD_DEMANDA  \
# 0               515   ANTOFAGASTA   1.072244    1.304258     0.707064
# 1               515         ARICA   0.175551    0.041857     0.140730
# 2               515        CALAMA   0.641342    0.219591     0.443948
# 3               515        CASTRO   0.406425    0.120733     0.300728
# 4               515       CHILLAN   0.762630    0.276593     0.511619
# ...             ...           ...        ...         ...          ...
# 23094        875225      VALDIVIA   0.004187    0.018505     0.004112
# 23095        875359  SANTIAGO SUR   0.238961    0.226827     0.242681
# 23096        875365       CURAUMA   0.342674    0.325524     0.342997
# 23097        875365  SANTIAGO SUR   0.238961    0.226827     0.242681
# 23098        875556  PUERTO MONTT   0.238961    0.226827     0.242681
#
#           DELTA
# 0      0.232014
# 1     -0.133694
# 2     -0.421751
# 3     -0.285692
# 4     -0.486038
# ...         ...
# ...

# %%
valor_por_sku = pd.read_csv('../data/valorSku.csv', error_bad_lines=False, encoding='UTF-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-adce283fb1c3> in <module>
# ----> 1 valor_por_sku = pd.read_csv('../data/valorSku.csv', error_bad_lines=False, encoding='UTF-8')
#
# ...

# %%
conversion = pd.read_csv('../data/conversiones_unidades.csv', encoding = "ISO-8859-1")[['ID_SKU_VENTA', 'CAJAS_POR_PALLET']]
sku_pallets = {}
for index, row in conversion.iterrows():
    sku_pallets[row['ID_SKU_VENTA']] = row['CAJAS_POR_PALLET']
valor_por_sku['Precio Pallet'] = valor_por_sku.apply(lambda x: x['Precio Caja'] * sku_pallets[x['SKU']], axis=1)
